# %% [markdown]
# # NeuroFate Project Overview
#
# This notebook is a placeholder for project orientation only. It contains no executed analysis and should not be used to launch heavy workflows during initiation.

# %% [markdown]
# ## Manual Execution Policy
#
# - LIGHTWEIGHT checks may inspect configs and small metadata tables.
# - HEAVY analysis commands must be copied from the README and run manually only after approval.
# - Do not load large `.h5ad`, `.h5`, `.zarr`, `.loom`, `.mtx`, or parquet data here yet.
